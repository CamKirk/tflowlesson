# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = {
    'x':[-3,-2,-1,0,1,2,3],
    'y':[9,4,1,0,1,4,9]
}
df = pd.DataFrame(data=data)

# %%
plt.scatter(df['x'],df['y'])

# %%
plt.plot(df['x'],df['y'])

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# $$\frac{\Sigma (y-y^{\prime2}))}{N_y}$$

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %%
plt.plot(df['x'],df['y']*2,'--',df['x'],df['y']*3,df['x'],df['y']*4,df['x'],df['y'] )
#plt.axes()
plt.show()

# %%
def graph(formula1, formula2, x_range):  
    x = np.array(x_range)  
    y = eval(formula)
    plt.plot(x, y)  
    plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t**2, 'r--', t, 2*t**2, 'bs', t, 3*t**2, 'g^')
plt.show()

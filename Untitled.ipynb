# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {
    'x':[-3,-2,-1,0,1,2,3],
    'y':[9,4,1,0,1,4,9]
}
df = pd.DataFrame(data=data)

# %%
plt.scatter(df['x'],df['y'])

# %%
plt.plot(df['x'],df['y'])

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# $$\frac{\Sigma (y-y^{\prime2}))}{N_y}$$

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %%
plt.plot(df['x'],df['y'])
plt.axes()
plt.show()
